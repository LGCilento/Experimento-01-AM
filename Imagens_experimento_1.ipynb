# %% [markdown]
# <a href="https://colab.research.google.com/github/LGCilento/Experimento-01-AM/blob/main/Imagens_experimento_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt ######-----Curva ROC para kNN padrão-----#########

# %% [markdown]
# # **Visualização de Dados obtidos no Experimento do k-NN**

# %% [markdown]
# **Base de dados KC2**

# %%
k = [1,2,3,5,7,9,11,13,15] 

#########----Dados obtidos a partir do teste para o k-NN padrão----###########
tp_rate_list_normal = [ 0.4354582917082917,  0.4400643800643801,  0.43576534576534576,  0.461031746031746,  0.4281074481074481,  0.45661560661560663,  0.38807581307581307,  0.40590035695298854,  0.38354062604062605]
fp_rate_list_normal = [0.12534582467639033, 0.14408155425327956, 0.09029664493855316, 0.08589607124490846, 0.06814184115897702, 0.07206760674760729, 0.06950320496873173, 0.06806443123084849, 0.06611547484681567]

#########----Dados obtidos a partir do teste para o k-NN com peso----###########
tp_rate_list_weith =  [0.40498567608861724, 0.4085714285714286, 0.4064824717765894, 0.438249666999667, 0.45074134199134197, 0.425506993006993, 0.4043179043179043, 0.37253325106266283, 0.3473015873015873]
fp_rate_list_weith =  [0.1402425525687755, 0.2095912455087482, 0.08777615403568928, 0.07608853324123738, 0.07489012469018141, 0.07430762232160056, 0.060235692963996994, 0.0608737197761588, 0.059417098232887704]

#########----Dados obtidos a partir do teste para o k-NN Adaptativo----###########
tp_rate_list_adaptative =  [0.4449050949050949, 0.4183430458430458, 0.3902930402930403, 0.4572344322344322, 0.4407936507936508, 0.4194871794871795, 0.4267715617715618, 0.38824675324675323, 0.35198051948051945]
fp_rate_list_adaptative =  [0.139068929431947, 0.13592980662748105, 0.07601604744461887, 0.08276924829556409, 0.0720575595060721, 0.0694785892152884, 0.06321097601585407, 0.06288383452143592, 0.05625862874116449]

# %%
fig1, ax = plt.subplots() ######-----Curva ROC -----#########
fig1.set_figheight(7)
fig1.set_figwidth(15)

ax.plot(fp_rate_list_adaptative, tp_rate_list_adaptative,'r^', label='k-NN adaptativo')
for i, txt in enumerate(k):
    ax.annotate(txt, (fp_rate_list_adaptative[i], tp_rate_list_adaptative[i]), fontsize=15)
ax.plot(fp_rate_list_weith, tp_rate_list_weith,'go', label='k-NN com peso')

for i, txt in enumerate(k):
    ax.annotate(txt, (fp_rate_list_weith[i], tp_rate_list_weith[i]), fontsize=15)

ax.plot(fp_rate_list_normal, tp_rate_list_normal,'bx',label='k-NN padrão')

for i, txt in enumerate(k):
    ax.annotate(txt, (fp_rate_list_normal[i], tp_rate_list_normal[i]), fontsize=15)

ax.set(xlabel='FP_rate', ylabel='TP_rate',title='ROC curve')
ax.grid()
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
fig1.savefig('image1.png', bbox_inches='tight')
plt.show()

# %%
fig1, ax = plt.subplots() ######-----Curva Evolução TP -----#########
fig1.set_figheight(7)
fig1.set_figwidth(15)

ax.plot(k, tp_rate_list_adaptative,marker='^',color='r', label='k-NN adaptativo')
ax.plot(k, tp_rate_list_weith,marker='o',color='g', label='k-NN com peso')
ax.plot(k, tp_rate_list_normal,marker='x',color='b',label='k-NN padrão')


ax.set(xlabel='K_Values', ylabel='TP_rate',title='TP_RATE')
ax.grid()
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
fig1.savefig('image2.png', bbox_inches='tight')
plt.show()

# %%
fig1, ax = plt.subplots() ######-----Curva Evolução FP -----#########
fig1.set_figheight(7)
fig1.set_figwidth(15)

ax.plot(k, fp_rate_list_adaptative,marker='^',color='r', label='k-NN adaptativo')
ax.plot(k, fp_rate_list_weith,marker='o',color='g', label='k-NN com peso')
ax.plot(k, fp_rate_list_normal,marker='x',color='b',label='k-NN padrão')


ax.set(xlabel='K_Values', ylabel='FP_rate',title='FP_RATE')
ax.grid()
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
fig1.savefig('image3.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Base KC1**

# %%
k = [1,2,3,5,7,9,11,13,15] 

#########----Dados obtidos a partir do teste para o k-NN padrão----###########
tp_rate_list_normal =[0.32246383362172837, 0.3072735810978888, 0.26841414529301527, 0.26170569795316245, 0.19654495254467447, 0.1896598957308676, 0.20442087281274102, 0.17735211324844802, 0.1754803527740451]
fp_rate_list_normal = [0.10495980049782212, 0.0940015760735814, 0.06684107534990355, 0.056596423773992426, 0.053675818701667925, 0.040808481908475636, 0.0396764261490846, 0.039728415481907586, 0.03461304071146229]


 
#########----Dados obtidos a partir do teste para o k-NN com peso----###########
tp_rate_list_weith =  [0.3269396808823786, 0.31258402591063883, 0.27774250104752135, 0.27847360161078305, 0.1983727600201716, 0.17877645610113876, 0.19785148240167705, 0.2062882353120044, 0.17997466112733077]
fp_rate_list_weith =  [0.0924945087495345 , 0.10933685380199602 , 0.07000254775212165 , 0.057993280024675534 , 0.05156026948017339 , 0.04487354418721858 , 0.04535287638259127 ,0.038002588775218546 ,0.03300750690330102]

#########----Dados obtidos a partir do teste para o k-NN Adaptativo----###########
tp_rate_list_adaptative =  [0.2998209529731722,0.3137362014698353,0.2602985559021028,0.2633365350847228,0.20177338790242016,0.19950853581901967,0.17891176383704846,0.17679851448106376,0.1993265084062048]
fp_rate_list_adaptative =  [0.09421286610769268,0.09073969135327813,0.06631634764939937,0.060008934559067174,0.05441465985206427,0.04436820089684224,0.04163622917302877,0.03657845060426126,0.03468093609771433]

# %%
fig1, ax = plt.subplots() ######-----Curva ROC -----#########
fig1.set_figheight(7)
fig1.set_figwidth(15)

ax.plot(fp_rate_list_adaptative, tp_rate_list_adaptative,'r^', label='k-NN adaptativo')
for i, txt in enumerate(k):
    ax.annotate(txt, (fp_rate_list_adaptative[i], tp_rate_list_adaptative[i]), fontsize=15)
ax.plot(fp_rate_list_weith, tp_rate_list_weith,'go', label='k-NN com peso')

for i, txt in enumerate(k):
    ax.annotate(txt, (fp_rate_list_weith[i], tp_rate_list_weith[i]), fontsize=15)

ax.plot(fp_rate_list_normal, tp_rate_list_normal,'bx',label='k-NN padrão')

for i, txt in enumerate(k):
    ax.annotate(txt, (fp_rate_list_normal[i], tp_rate_list_normal[i]), fontsize=15)

ax.set(xlabel='FP_rate', ylabel='TP_rate',title='ROC curve')
ax.grid()
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1,loc='upper left')
fig1.savefig('image4.png', bbox_inches='tight')
plt.show()

# %%
fig1, ax = plt.subplots() ######-----Curva Evolução TP -----#########
fig1.set_figheight(7)
fig1.set_figwidth(15)

ax.plot(k, tp_rate_list_adaptative,marker='^',color='r', label='k-NN adaptativo')
ax.plot(k, tp_rate_list_weith,marker='o',color='g', label='k-NN com peso')
ax.plot(k, tp_rate_list_normal,marker='x',color='b',label='k-NN padrão')


ax.set(xlabel='K_Values', ylabel='TP_rate',title='TP_RATE')
ax.grid()
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
fig1.savefig('image5.png', bbox_inches='tight')
plt.show()

# %%
fig1, ax = plt.subplots() ######-----Curva Evolução FP -----#########
fig1.set_figheight(7)
fig1.set_figwidth(15)

ax.plot(k, fp_rate_list_adaptative,marker='^',color='r', label='k-NN adaptativo')
ax.plot(k, fp_rate_list_weith,marker='o',color='g', label='k-NN com peso')
ax.plot(k, fp_rate_list_normal,marker='x',color='b',label='k-NN padrão')


ax.set(xlabel='K_Values', ylabel='FP_rate',title='FP_RATE')
ax.grid()
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
fig1.savefig('image6.png', bbox_inches='tight')
plt.show()
